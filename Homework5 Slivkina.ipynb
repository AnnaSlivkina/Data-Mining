# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
from statsmodels.sandbox.stats.multicomp import multipletests
from sklearn.utils import resample

# %%
data = pd.read_excel('salaries.xls', index_col=0)
tests = []

# %%
data.describe()
# Out:
#           Unnamed: 0        Agency      Salary2010      Salary2011  \
# count   52256.000000  52256.000000    52256.000000    52256.000000
# mean   156430.169205    409.339655    49380.667234    52126.387133
# std     89673.627737    155.483410    33914.308198    34439.595622
# min        10.000000     11.000000      100.000000      100.000000
# 25%     83462.750000    305.000000    30432.500000    33795.000000
# 50%    155251.000000    360.000000    46322.000000    48187.000000
# 75%    225747.500000    490.000000    64223.250000    66045.000000
# max    339762.000000    696.000000  1982918.000000  2529168.000000
#
#            Salary2012      Salary2013
# count    52256.000000    52256.000000
# mean     52511.053027    50305.860284
# std      35238.704485    36724.706184
# min        102.000000      101.000000
# 25%      33929.750000    30654.500000
# 50%      48889.500000    47093.000000
# 75%      66337.250000    65640.250000
# max    2736431.000000  2633642.000000

# %%
Задание 1
Задание 1.1
Одновыборочный параметрический тест
H0 : Средняя зарплата политического аналитика в 2010 году была равна 49380
H1 : Средняя зарплата политического аналитика в 2010 году отличается от 49380

# %%
#Одновыборочный тест Стьюдента
t_score = (np.mean(data['Salary2010']) - 49380) / (np.std(data['Salary2010']) / (data['Salary2010'].size) ** 0.5)
#правосторонняя
p_value = 1 - stats.t.cdf(t_score, data['Salary2010'].size - 1)
tests.append(p_value)
print p_value
# Out:
# 0.498205786099

# %%
p_value = 0.498205786099
Следовательно, гипотеза H0 не отвергается

# %%
#t = data[(data.JobTitle == u'SENIOR ACTUARIAL ANALYST')&(data.JobTitle == u'ADM LAW JDGE 3')]
model_list = ['SENIOR ACTUARIAL ANALYST', 'ADM LAW JDGE 3']
data[data['JobTitle'].isin(model_list)].groupby("JobTitle")[[ 'Salary2011']].agg(['mean'])
data
# Out:
#        Unnamed: 0  Agency              AgencyTitle  \
# 2              10     165              Accountancy
# 5              36     165              Accountancy
# 6              44      35                  Actuary
# 7              45      35                  Actuary
# 8              47      35                  Actuary
# 9              48      35                  Actuary
# 10             52      35                  Actuary
# 11             58      35                  Actuary
# 12             59      35                  Actuary
# 13             60      35                  Actuary
# 17             76     110  Administrative Hearings
# 21            105     110  Administrative Hearings
# 22            107     110  Administrative Hearings
# 23            108     110  Administrative Hearings
# 24            112     110  Administrative Hearings
# 25            123     110  Administrative Hearings
# 26            124     110  Administrative Hearings
# 27            129     110  Administrative Hearings
# 28            137     110  Administrative Hearings
# 29            139     110  Administrative Hearings
# 30            140     110  Administrative Hearings
# 31            158     110  Administrative Hearings
# 32            172     110  Administrative Hearings
# 33            175     110  Administrative Hearings
# 34            177     110  Administrative Hearings
# 35            181     110  Administrative Hearings
# 36            197     110  Administrative Hearings
# 37            209     110  Administrative Hearings
# 38            210     110  Administrative Hearings
# 39            213     110  Administrative Hearings
# ...           ...     ...                      ...
# 79049      339673     691    Yakima Valley College
# 79050      339674     691    Yakima Valley College
# 79051      339676     691    Yakima Valley College
# 79052      339679     691    Yakima Valley College
# 79053      339680     691    Yakima Valley College
# 79054      339681     691    Yakima Valley College
# 79055      339686     691    Yakima Valley College
# 79056      339687     691    Yakima Valley College
# 79059      339693     691    Yakima Valley College
# 79061      339699     691    Yakima Valley College
# 79062      339703     691    Yakima Valley College
# 79065      339714     691    Yakima Valley College
# 79066      339716     691    Yakima Valley College
# 79067      339717     691    Yakima Valley College
# 79068      339720     691    Yakima Valley College
# 79069      339721     691    Yakima Valley College
# 79070      339722     691    Yakima Valley College
# 79071      339726     691    Yakima Valley College
# 79072      339728     691    Yakima Valley College
# 79073      339732     691    Yakima Valley College
# 79074      339736     691    Yakima Valley College
# 79075      339739     691    Yakima Valley College
# 79076      339744     691    Yakima Valley College
# 79078      339747     691    Yakima Valley College
# 79079      339752     691    Yakima Valley College
# 79080      339753     691    Yakima Valley College
# 79081      339754     691    Yakima Valley College
# 79082      339758     691    Yakima Valley College
# 79083      339759     691    Yakima Valley College
# 79084      339762     691    Yakima Valley College
#
#                             EmployeeName                         JobTitle  \
# 2                     JOLICOEUR, EDWIN G                     BOARD MEMBER
# 5                          SWEENEY, RICK                   EXEC. DIRECTOR
# 6                    BURKHART, KELLY RAE  ADMINISTRATIVE SERVICES MANAGER
# 7                        DEMPSEY, TROY A         SENIOR ACTUARIAL ANALYST
# 8                       GUTIERREZ, AARON                   POLICY ANALYST
# 9                       HARBOUR, MICHAEL                ACTUARIAL ANALYST
# 10                     HYDE, ELIZABETH R               PUB SPEC/WEBMASTER
# 11                      SMITH, MATTHEW M                    STATE ACTUARY
# 12                   STEELE, CHRISTINE L         SENIOR ACTUARIAL ANALYST
# 13                        STINEMAN, KYLE                ACTUARIAL ANALYST
# 17                   BAKER, JENNIFER LEE               OFFICE ASSISTANT 3
# 21                       BOIVIN, BARBARA                   ADM LAW JDGE 3
# 22                       BOLONG, HEIDI G                   ADM LAW JDGE 3
# 23                    BOLONG, RANDOLPH F                   ADM LAW JDGE 3
# 24                    BOUCHER, DEBORAH S                LEGAL SECRETARY 1
# 25                        BRISKI, JOANNA               OFFICE ASSISTANT 3
# 26     BRYAN JR, COURTNEY EDWARD BARRETT               OFFICE ASSISTANT 3
# 27                       BURDUE, CINDY L                   ADM LAW JDGE 3
# 28                 CAMPAGNA, ELIZABETH L               OFFICE ASSISTANT 3
# 29                      CAMPBELL, CARY L                LEGAL SECRETARY 3
# 30                     CANFIELD, ELMER E                   ADM LAW JDGE 3
# 31                       COLLINS, RUTH L               OFFICE ASSISTANT 3
# 32              DANIELL, CATHERINE LYNNE                LEGAL SECRETARY 1
# 33                      DAVENPORT, CRAIG                   ADM LAW JDGE 3
# 34          DEMARAY-WASSON, JEANNE RENEE               OFFICE ASSISTANT 3
# 35                  DICKERSON, NATALEE R                LEGAL SECRETARY 1
# 36                   EMMAL, JULIE KENDIG                   ADM LAW JDGE 3
# 37            FAGER, KRISTINA M PETGRAVE                   ADM LAW JDGE 3
# 38                      FARRELL, EDITH M                LEGAL SECRETARY 1
# 39                    FIANDER, DEBORAH J                   ADM LAW JDGE 3
# ...                                  ...                              ...
# 79049                    TREVINO, EUGENE                      CUSTODIAN 1
# 79050             TRIPP, ELIZABETH MARIE                          FACULTY
# 79051                      TUCK, DIANA M                          FACULTY
# 79052                 UNDERWOOD, SHAWN D                      CUSTODIAN 1
# 79053            URRUTIA, STEVEN ANTHONY                          FACULTY
# 79054                   VACA, REYNALDO R                      CUSTODIAN 1
# 79055                  VALDEZ, RICARDO G                          FACULTY
# 79056                    VALDEZ, VIOLETA           BILINGUAL PROGRAM ASST
# 79059                   VANWINSEN, CATHY                PROGRAM ASSISTANT
# 79061                       VERA, DENISE                PROGRAM ASSISTANT
# 79062                 VILLALOVOS, ANDY F                      CUSTODIAN 1
# 79065               WALKER, MONTGOMERY B                          FACULTY
# 79066                 WALLACE, MICHAEL A                          FACULTY
# 79067                  WARNER, TIMOTHY B                          FACULTY
# 79068                  WATSON JR, JOHN W                          FACULTY
# 79069              WAUZYNSKI, TIMMOTHY E                          FACULTY
# 79070               WAYENBERG, WILLIAM K                          FACULTY
# 79071                     WEDAM, SUSAN M                          FACULTY
# 79072                   WEDIN, RICHARD D                          FACULTY
# 79073                    WEST, SUZANNE M       EXECUTIVE ASST TO PRESIDEN
# 79074                     WIDNER, JILL E                          FACULTY
# 79075                   WILKINS, SHERI R                          FACULTY
# 79076                  WILSON, DEBORAH F         COORD-VOLUNTEER CTR PROG
# 79078                   WILSON, LONDON E                          FACULTY
# 79079                  WOLFE, CLARISSA A          DIR-ACCOUNTING SERVICES
# 79080                      WOOD, JEFFERY          DIR-FACILITY OPERATIONS
# 79081                      WOOD, SUSAN P                          FACULTY
# 79082                    WRIGHT, TERRY D                          FACULTY
# 79083                      YBARRA, TOMAS       VICE PRES-INSTR & STU SERV
# 79084                  ZONTEK, KENNETH S                          FACULTY
#
#        Salary2010  Salary2011  Salary2012  Salary2013
# 2             750         950         450         300
# 5           92573       91078       91536       92952
# 6           78905       77458       76560       78726
# 7           81542       86883      105468       66491
# 8           69468       68703       67656       69570
# 9           54310       53699       52884       58958
# 10          63074       62092       61284       62232
# 11         173197      171249      174256      191552
# 12          74824       73983       72852       75876
# 13          52730       56218       55560       59076
# 17          33278       24114       19236       17803
# 21          61806       60214       58213       61965
# 22          73260       72162       71064       29610
# 23          80892       79680       78468       32695
# 24          40075       39235       38328       39930
# 25          24260       29816       30762       32720
# 26          28336       29672       30352       30836
# 27          57299       39234       78468       79882
# 28          30686       31659       32460       32964
# 29          46131       45677       45750       45560
# 30          80892       79680       78468       87400
# 31          33468       32964       32809       33360
# 32          39516       37359       34630       33329
# 33          80892       79680       78468       79882
# 34          34735       33241       32648       33073
# 35          39710       38922       38328       39426
# 36          80892       79680       78468       79882
# 37          52832       49407       53302       52152
# 38          30149       38522       37997       38245
# 39          80892       79680       78468       79882
# ...           ...         ...         ...         ...
# 79049       30889       31141       31141       31141
# 79050        9605       16738       14626       16631
# 79051       21588       13314       13314       13314
# 79052       31141       31141       31141       31141
# 79053        5852        5852        5852        5657
# 79054       26431       27635       28104       28062
# 79055        5706       17118       11412       11412
# 79056       36109       35433       34848       35246
# 79059       34260       33787       33228       34059
# 79061       34260       33050       33093       33784
# 79062       30961       31257       30929       30986
# 79065       73638       66031       58557       60137
# 79066        8559       13790       13948        6657
# 79067        1902        1902        1427         476
# 79068        4121        7925        3487        1268
# 79069        6340        6340        5548        6340
# 79070       27864       19179       26152       27018
# 79071       69846       71284       69912       74669
# 79072        8876        5072        5178        5072
# 79073       52029       51314       23973       23156
# 79074       60594       60098       57276       56143
# 79075       62686       62788       62189       61662
# 79076       41016       40480       39846       40830
# 79078        3452        2640        3655        3076
# 79079       58361       61447       60435       62006
# 79080       70030       69068       67930       73857
# 79081       18449       17689       15965       18881
# 79082        5706       17118       15692       12839
# 79083      100989       99601       97960      100506
# 79084       64009       60356       10968       53340
#
# [52256 rows x 9 columns]

# %%
Задание 1.2
Двухвыборочный тест:
H0 : Средняя зарплата SENIOR ACTUARIAL ANALYST и ADM LAW JDGE 3 в 2011 не отличается
H1 : У SENIOR ACTUARIAL ANALYST средняя зарплата в 2012 году больше

# %%
#Двухвыборочный тест Стьюдента
first = data[data['JobTitle'] == 'SENIOR ACTUARIAL ANALYST']['Salary2011']
second = data[data['JobTitle'] == 'ADM LAW JDGE 3']['Salary2011']
print first.std()
print second.std()
s1 = np.std(first) ** 2 / first.size
s2 = np.std(second) ** 2 / second.size
#Дисперсия этой разности равна исходя из независимости выборок: 
V = np.sqrt( s1 +  s2)
#Распределение t-статистики: 
df = (s1 + s2) ** 2 / ( s1 ** 2 / (first.size - 1) + s2 ** 2 / (second.size - 1))
t_score = (np.mean(first) - np.mean(second)) / V
print 't_score', t_score
p_value = 1 - stats.t.cdf(t_score, df)
tests.append(p_value)
print 'p-value',p_value
# Out:
# 9121.67747731
# 21509.7965928
# t_score 2.21186330428
# p-value 0.0573834022539

# %%
Получаем p-value ~ 0.057, на уровне значимости 0.05 гипотеза H0  не отвергается.

# %%
Двухвыборочный непараметрический тест
H0 : Вероятность того, что SENIOR ACTUARIAL ANALYST получает больше ADM LAW JDGE 3 в 2011 равна 0.5
H1 : Вероятность того, что SENIOR ACTUARIAL ANALYST получает больше ADM LAW JDGE 3 в 2012 больше 0.5

# %%
#Применим U-тест Манна - Уитни
from scipy.stats import mannwhitneyu
U_test = mannwhitneyu(first, second)
tests.append(U_test[1])
print U_test
# Out:
# (17.0, 0.16592895345135578)

# %%
p-value ~ 0.166, на уровне значимости 0.005 гипотезу Н0 не отвергаем

# %%
Задание 1.3
Непараметрический тест для парных наблюдений
H0: Медиана зарплат BOARD MEMBER за 2012 год не отличается от медианы за 2013 год
H1: Медиана отличается

# %%
from scipy.special import binom

#Знаковый критерий
board_salary2012 = data[data['JobTitle'] == 'BOARD MEMBER']['Salary2012']
board_salary2013 = data[data['JobTitle'] == 'BOARD MEMBER']['Salary2013']

a = np.sum(board_salary2012 < board_salary2013)
b = np.sum(board_salary2012 != board_salary2013)

if a > b / 2:
    p_value = np.sum(binom(b, x) for x in xrange(a, b + 1)) * (0.5 ** b) * 2
else:
    p_value = np.sum(binom(b, x) for x in xrange(0, a + 1)) * (0.5 ** b) * 2

tests.append(p_value)
print p_value
# Out:
# 0.5078125

# %%
p-value ~ 0.51, на уровне значимости 0.005 гипотезу Н0 не отвергаем

# %%
Параметрический тест для парных наблюдений
H0: Средняя зарплата Administrative Office of the Courts равна в 2010 и 2011 годах
H1: Средняя зарплата Administrative Office of the Courts больше в 2011 году

# %%
agency_salary = data[data.AgencyTitle == 'Administrative Hearings']
office2010 = agency_salary['Salary2010']
office2011 = agency_salary['Salary2011']
razn = office2010 - office2011
office_mean = np.mean(razn)
office_sd = np.std(razn)
t_value = office_mean / (office_sd / np.sqrt(razn.size))
p_value = 1 - stats.t.cdf(t_value, razn.size - 1)
tests.append(p_value)
print p_value
# Out:
# 0.119383049695

# %%
p-value ~ 0.12, на уровне значимости 0.005 гипотезу Н0 не отвергаем

# %%
Задание 2
Точная альтернативная гипотеза для последнего теста: 
H1 : Средняя зарплата в 2010 году была больше на 5%

# %%
#Вероятность того, что мы правильно отклоним H0
x = stats.t.ppf(0.975, razn.size - 1) * np.std(razn) / razn.size
power = 1 - stats.t.cdf((x - np.mean(office2011) * 0.10)/(np.std(razn) / np.sqrt(razn.size)), razn.size - 1)
print 'Мощность критерия', power
# Out:
# Мощность критерия 0.960896781336

# %%
#Задание 3
print tests
error_rate = 0.05
rejections = np.sum(tests < error_rate)
print 'Отклонения: ', rejections
# Out:
# [0.4982057860989979, 0.057383402253872395, 0.16592895345135578, 0.5078125, 0.11938304969504909]
# Отклонения:  0

# %%
reject, pvals_corrected, alphacSidak, alphacBonf = multipletests(tests, alpha=0.05, method='fdr_bh', returnsorted=False)
print 'Отклонения для Benjamini/Hochberg  (non-negative):' , np.sum(reject)
# Out:
# Отклонения для Benjamini/Hochberg  (non-negative): 0

# %%
reject, pvals_corrected, alphacSidak, alphacBonf = multipletests(tests, alpha=0.05, method='bonferroni', returnsorted=False)
print 'Отклонения после одношаговой коррекции Bonferroni:' , np.sum(reject)
# Out:
# Отклонения после одношаговой коррекции Bonferroni: 0

# %%
reject, pvals_corrected, alphacSidak, alphacBonf = multipletests(tests, alpha=0.05, method='sidak', returnsorted=False)
print 'Отклонения после одношаговой коррекции Sidak:' , np.sum(reject)
# Out:
# Отклонения после одношаговой коррекции Sidak: 0

# %%
reject, pvals_corrected, alphacSidak, alphacBonf = multipletests(tests, alpha=0.05, method='holm', returnsorted=False)
print 'Отклонения для step-down method using Bonferroni adjustments:' , np.sum(reject)
# Out:
# Отклонения для step-down method using Bonferroni adjustments: 0

# %%
Результаты не изменились после поправки на множественное тестирование

# %%
Задание 4
Найдем доверительный интервал для средней зарплаты в Big Bend Community College в 2012

# %%
college2012 = data[data['AgencyTitle'] == "Big Bend Community College"]['Salary2012']
college2012_size = college2012.size
college2012_mean = np.mean(college2012)
step = stats.norm.ppf(0.975) * np.std(college2012) / np.sqrt(college2012.size)
print "Доверительный интервал:",college2012_mean - step,':', college2012_mean + step
# Out:
# Доверительный интервал: 31908.9176551 : 39296.9882273

# %%
college2012_median = np.median(college2012)
nsamples = 1000
                                                                 
samplesize=len(college2012)
n = samplesize
X = []
for i in range(nsamples):
    college2012_resample = college2012_median - resample(college2012, replace = True).median()
    X.append(college2012_resample)
X.sort()
boundary1, boundary2 = np.percentile(X, q = [5, 95])
print "Непарметрический интервал для медианы на основе бустрепа:",college2012_median - boundary2,':', college2012_median - boundary1
# Out:
# Непарметрический интервал для медианы на основе бустрепа: 29726.0 : 36756.0
